# %%
import loompy
import glob
import velocyto as vcy
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
files = sorted(glob.glob('/data/sc-10x/data-runs/171120-scheele-adipose/180831_10x_s*/velocyto/*.loom'))

loompy.combine(files, '/projects/pytrik/sc_adipose/analyze_10x_fluidigm/data/velocyto/180831.loom', key="Accession")

# %%
vlm = vcy.VelocytoLoom('/projects/pytrik/sc_adipose/analyze_10x_fluidigm/data/velocyto/180831.loom')

# %%
print(vlm.ca['CellID'])
# Out:
# []

# %%
print(set(list(map(lambda x: x.split(':')[0], vlm.ca['CellID']))))
# Out:
# {'180831_10x_s3', '180831_10x_s1', '180831_10x_s4', '180831_10x_s2', '180831_10x_s5'}

# %%
#vlm.ca['timepoint'] = np.asarray(list(map(lambda x: 'T' + x.split('_')[-1][1], vlm.ca['CellID'])))

# %%
vlm.ca['CellID'] = np.asarray(list(map(lambda x: x.split(':')[1][:-1] + '-' + x[12], vlm.ca['CellID'])))
vlm.ca['CellID']
# Out:
# array(['AAACCTGCACCTTGTC-1', 'AAAGTAGCAAGGACTG-1', 'AAACGGGGTCACTGGC-1',
#        ..., 'TTTGCGCGTGTGACGA-5', 'TTTATGCTCCTCTAGC-5',
#        'TTTGTCAGTGACGCCT-5'],
#       dtype='<U18')

# %%
metadata = pd.read_table('/projects/pytrik/sc_adipose/analyze_10x_fluidigm/data/velocyto/180831_metadata.txt', sep='\t')

# %%
metadata
# Out:
#        nGene   nUMI     orig.ident timepoint time.combined  percent.ribo  \
# 0       4614  23660  SeuratProject        T1        T1T2T3             0
# 1       3584  15599  SeuratProject        T1        T1T2T3             0
# 2       2979  13379  SeuratProject        T1        T1T2T3             0
# 3       3051  11689  SeuratProject        T1        T1T2T3             0
# 4       4084  18077  SeuratProject        T1        T1T2T3             0
# 5       3351  14168  SeuratProject        T1        T1T2T3             0
# 6       3139  15634  SeuratProject        T1        T1T2T3             0
# 7       5115  30228  SeuratProject        T1        T1T2T3             0
# 8       3585  17739  SeuratProject        T1        T1T2T3             0
# 9       4745  23365  SeuratProject        T1        T1T2T3             0
# 10      3663  15868  SeuratProject        T1        T1T2T3             0
# 11      5569  33256  SeuratProject        T1        T1T2T3             0
# 12      4810  30906  SeuratProject        T1        T1T2T3             0
# 13      3625  18102  SeuratProject        T1        T1T2T3             0
# 14      4227  21411  SeuratProject        T1        T1T2T3             0
# 15      4218  20360  SeuratProject        T1        T1T2T3             0
# 16      4100  21108  SeuratProject        T1        T1T2T3             0
# 17      1593   4300  SeuratProject        T1        T1T2T3             0
# 18      3725  19321  SeuratProject        T1        T1T2T3             0
# 19      5306  32796  SeuratProject        T1        T1T2T3             0
# 20      1995   6282  SeuratProject        T1        T1T2T3             0
# 21      4132  21865  SeuratProject        T1        T1T2T3             0
# 22      4915  26239  SeuratProject        T1        T1T2T3             0
# 23      3788  15939  SeuratProject        T1        T1T2T3             0
# 24      4142  22670  SeuratProject        T1        T1T2T3             0
# 25      4352  23772  SeuratProject        T1        T1T2T3             0
# 26      3942  19979  SeuratProject        T1        T1T2T3             0
# 16           3        3      0        1        3     26
# 17           2        2     14       13       15     15
# 18           7        7      8        8        8     20
# 19           7        7      8        8        8      9
# 20           7        7      8        8        8      9
# 21           7        7      8        8        8      9
# 22           7        7      8        8        8      9
# 23           1        1     12       11       13     18
# 24           2        2     14       13       15     15
# 25           3        3      0        1        3     23
# 26           7        7      8        8        8      9
# 27           7        7      8        8        8      9
# 28           7        7      8        8        8      9
# 29           7        7     12       11       13      9
# ...        ...      ...    ...      ...      ...    ...
# 26842        6        6      5        5        4      1
# 26843        6        6      5        5        4      1
# 26844        0        0      4        4        2      0
# 26845        6        6      5        5        4      1
# 26846        6        6      5        5        4      1
# 26847        0        0      6        6        5      2
# 26848        0        0      6        6        5      2
# 26849        0        0      6        6        5      2
# 26850        0        0      4        4       16     16
# 26851        6        6      5        5        4      1
# 26852        0        0      4        4        2      0
# 26853        0        0      4        4       16     16
# 26854        0        0      6        6        5      2
# 26855        0        0      4        4        2      0
# 26856        9        9     10       14       17     21
# 26857        0        0      6        6        5      2
# 26858        0        0      4        4        2      0
# 26859        0        0      6        6        5      2
# 26860        0        0      4        4       16     16
# 26861        0        0      6        6        5      2
# 26862        0        0      4        4        2      0
# 26863        0        0      4        4        2      0
# 26864        6        6      5        5        4      1
# 26865        6        6      5        5        4      1
# 26866        6        6      5        5        4      1
# 26867        0        0      4        4       16     16
# 26868        0        0      6        6        5      2
# 26869        0        0      6        6        5      2
# 26870        9        9     10       15       18     22
# 26871        0        0      4        4        2      0
#
# [26872 rows x 19 columns]

# %%
metadata['CellID'] = metadata.index

# %%
#metadata['CellID'] = metadata[['CellID-old', 'sample_name']].apply(lambda x: x[1] + ':' + x[0].split('-')[0] + 'x', axis=1)

# %%
cells_to_keep = np.array(metadata['CellID'].tolist())
cellids_vlm = np.array(vlm.ca['CellID'])

vlm.filter_cells(bool_array=np.isin(cellids_vlm, cells_to_keep))

# %%
print(len(vlm.ca['CellID']))
# Out:
# 0

# %%
ca_df = pd.DataFrame(vlm.ca)
ca_df.shape
# Out:
# (26871, 4)

# %%
merged = ca_df.merge(metadata, on='CellID', how='left')

# %%
print(merged.shape)
# Out:
# (26871, 21)

# %%
merged = merged.to_dict('list')

# %%
print(merged.keys())
# Out:
# dict_keys(['CellID', 'Clusters', '_X', '_Y', 'nGene', 'nUMI', 'orig.ident', 'timepoint', 'percent.ribo', 'percent.mito', 'S.Score', 'G2M.Score', 'Phase', 'old.ident', 'res.0.3', 'res.0.5', 'res.0.7', 'res.1', 'res.1.2', 'res.1.5', 'res.2'])

# %%
#vlm.ca['CellID'] = np.asarray([x.encode('utf8') for x in vlm.ca['CellID']])
#vlm.ca['timepoint'] = np.asarray([x.encode('utf8') for x in vlm.ca['sample_name']])

for key in merged:
    try:
        vlm.ca[key] = np.asarray([x.encode('utf8') for x in merged[key]])
    except:
        vlm.ca[key] = np.asarray(merged[key])

# %%
vlm.to_hdf5('/projects/pytrik/sc_adipose/analyze_10x_fluidigm/data/velocyto/180831.hdf5')
